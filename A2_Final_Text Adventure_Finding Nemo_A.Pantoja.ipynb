# %% [markdown]
# # Welcome to the "Finding Nemo Text Adventure Game!"
#
# This game is based on the movie Finding Nemo, in which you will be located around the Great Barrier Reef playing as the main character: Nemo and trying to find a way to return home.
#
#
# You will try to escape some different scenes or complete tasks to level-up and reach the next level. According to where you are in the game you will have different options to step to another level and keep playing, or to lose. Be wise in your answers and follow your intuition. While swimming you will meet characters from the movie, such as Squirt, a young marine turtle, or Bruce a big and scary shark.
#
# I am sure you will do great, and Don't worry you will have an option to start all over again if that is the case.
#
# Do your best and good luck!
#
#
# Source: Chicago. Unkrich, Lee, and Andrew Stanton. 2003. Finding Nemo. United States: Buena Vista Pictures.

# %%
# Printing welcome message and introduction to the game

welcome = input(prompt=
"""
Hello! Welcome to the "Finding Nemo Game"

This is a text adventure game in which you will be Nemo and will be trying to return home.

Are you ready for the adventure? 


  
  ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢀⣀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢀⣠⣾⣿⣿⣷⣄⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢀⡔⠭⠍⡙⠉⠔⠁⠀⠈⠻⣿⣇⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣸⠄⡀⠀⠀⢀⣉⣈⠁⢢⠀⢹⣿⡆⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢀⠎⢠⣴⣶⠀⠌⠀⣀⣀⢱⠀⡇⠀⣿⣷⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣀⣀⣀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢸⠀⣿⣿⡟⢸⠀⣼⣿⣿⡿⠀⡇⠀⢸⣿⡀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⣠⣾⣿⣿⣿⣿⣷⣶⣄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⢢⠼⠋⠀⠈⢆⠹⠿⡿⠁⡸⠀⠀⢸⣿⡇⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠻⣿⣿⣿⣿⣿⣿⣿⣿⠿⠓⢐⣄⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⡇⠀⠀⠀⠀⠀⠈⠁⠀⢠⠃⣠⡄⢸⣿⣿⠀⠀⠀⢀⣀⡀
⠀⠀⠀⠀⠀⠀⠀⢀⣀⡀⠈⢿⣿⣿⣿⣿⡟⢡⣴⣾⣿⣿⣿⣆⠀⠀⠀⠀⠀⠀⠀⡤⠊⠀⠀⠀⠀⠀⠀⠀⠀⠀⡌⣼⣿⡇⠈⡏⠙⠀⡠⣖⣵⠏⠀
⠀⠀⠀⠀⠀⠀⣸⣿⣿⣿⡀⠀⠙⢿⣿⣿⢁⣿⣿⣿⣿⣿⣿⣯⡁⠀⠀⠀⠀⠀⠀⢆⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⡇⣿⣿⡇⠀⠈⢈⣡⣾⣿⣿⠀⠀
⠀⢀⣤⣶⣶⣶⣾⡙⣿⣿⣷⡀⢰⣶⣿⣿⢸⣿⡿⣫⣍⠙⣿⣿⣇⣰⡄⠀⠀⠀⠀⡎⢿⡷⠒⠂⠀⠀⠀⠀⠀⠀⠇⠙⠛⠁⠀⢠⣿⣿⣿⣿⣿⡆⠀
⢠⣿⣿⣿⣿⣿⣿⣷⡙⢿⣿⣧⠘⠿⢻⣿⣸⣿⣇⠈⠉⣀⣾⣿⣿⣿⠇⠀⠀⠀⠈⠦⢤⠀⠀⠀⠀⠀⠀⠀⠀⠀⠘⢄⣠⠖⣣⢸⣿⣿⣿⣿⣿⠇⠀
⢸⣿⣿⣿⣿⣿⣿⣿⡇⣸⣿⣿⡆⢀⣾⣿⣧⢿⣿⣿⣿⣿⣿⣭⣽⡟⠀⠀⠀⠀⠀⢀⣼⡆⠀⠀⠀⠀⠀⠀⠀⣀⣢⡀⠀⡴⠉⢜⣿⣿⣿⣿⡟⠀⠀
⠈⢿⣿⣿⣿⣿⠟⠁⠀⠘⠛⠛⠁⠀⠀⠈⢿⠏⠛⠛⠛⠛⠛⠋⠁⠀⠀⠀⢀⣤⣾⣿⣿⣧⠀⠀⠀⠀⠀⠘⣸⣿⣿⣿⣞⠀⠀⠈⣾⣿⣿⠟⠀⠀⠀
⠀⠀⠉⠙⠋⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣰⣿⣿⣿⣿⠟⠉⢦⠀⠀⠀⠀⠀⠘⣿⣿⣿⣿⠀⠀⠀⢸⠟⠁⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠋⠁⠀⠀⠀⠀⠀⠀⠙⠲⠤⠤⠔⠊⠁⠉⠻⣿⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
  
___ ___       _   ___ _     _                 
  |   |  |\/| |_    | / \   |_) |   /\ \_/ | | 
  |  _|_ |  | |_    | \_/   |   |_ /--\ |  o o 
  
 Press enter to start! >""")

import random

#Define scene_1: On the Great Barrier Reef the game starts set very deep at the ocean where 
#ocean where the sharks are around.
def scene_1():
    
    #Sharks is the variable #1 in the game and a list of strings to define 
    #the different sharks in the game
    shark_leader = ["Bruce", "Brucey"]
    random_leader = random.choice(shark_leader)
    shark_friends = [ "Chum","Chummy","Kevin", "Anchor"]
    random_friends = random.choice(shark_friends)
    
    #Introduction
    print("You are lost at the sea trying to find a way back home.\n")
    print("Far away and very deep in the ocean where there is not much sunlight...\n")
    print("Look! There is a a group of sharks.\n")
    
    #Prompt to enter and continue keep the order of the story
    input(prompt='<Press enter to continue>\n')
    
    #Added the name of the sharks from the list created
    #according to their index 0,1,2 to use them in order. 
    print("The leader of the sharks is ", random_leader)
    print("Talking about how hungry he is to his friend shark", random_friends)
    
    #Prompt to enter and continue keep the order of the story
    input(prompt='<Press enter to continue>\n')
    print("Nemo, I think is better to escape or you could be lunch today!\n")
          
    input(prompt='<Press enter to continue>\n')
    
    print("You observe to your sides...")
    print("Right next to you there is the East Australian Current and some coral reefs.\n")
    
    input(prompt='<Press enter to continue>\n')
    print("You can try to jump in the current, or try to hide at the coral reef.\n")
    print("What would you like to do? Pick a number to answer 1 or 2.\n")
    print("1. Jump to the East Australian Current")
    print("2. Hide on the Coral Reefs")
    
    #Variable #2 and user input to make a choice
    choice = input(prompt='>\n')
    
    #First nested conditional to give different choices to the player
    #Using IN to give the user different options to chose their answer
    if choice in ["1","one","ONE","i","I"]:
        
        print("Wohoo! It seems like you escape the sharks and enter a sea current.")
        print("Congratulations, now you enter the East Australian Current!")
        input(prompt='<Press enter to continue>\n')
        scene_2()
        
    elif choice in ["2","two","TWO","ii","II"]:
        print("You hide on the Coral Reefs.")
        print("Oh no! They find you.")
        fail()
    
    else:
        print("Invalid choice. Please try again.")
        input(prompt='<Press enter to restart the game>\n')
        scene_1()
        
from time import sleep

def scene_2():
    
    print("Great job Nemo! You are at the largest current of the sea.\n")
    print("This current flows in a southward direction from the Great Barrier Reef.\n")
    input(prompt='<Press enter to continue>\n')
    
    print("Oh look! You friend Squirt, a young turtle is here.\n")
    print("Squirt knows the sea currents and the shortcuts, you can ask him directions to return home.\n")
    
    print("What would you like to do? Pick numbers 1 or 2. \n")
    print("1. Ask Squirt for directions")
    print("2. Avoid Squirt ")
    
    #Get user input and offer different choices
    choice = input(prompt="> ").lower()
    
    #Second nested conditional to give different choices to the player
    #Code for choice 1
    if choice in ["1","one","i"]:
        print("Squirt is so happy to see you and give you the directions you need.\n")
        
        expected_input = 'count'
        actual_input = input(prompt='Write count to start counting <Press enter to continue>\n')

        while actual_input.lower() != expected_input:
            actual_input = input(prompt='Please enter the word "count" to start counting\n')

        # continue with the rest of the code once the input matches the expected string
        num_reefs = random.randint(3, 5)
        print(f"Squirt tells you that you need to pass the next {num_reefs} coral reefs, and enter the last one.\n")

        input(prompt='<Press enter to continue>\n')

        print("Pay attention! It's time to start counting.\n")

        # while loop to count the number of coral reefs
        count = 0

        while count < num_reefs:
            count += 1
            print(f"Coral Reef: {count}")
            sleep(1)

        print("Congratulations! You have successfully passed all the coral reefs and entered the last one.")
        input(prompt='<Press enter to continue>\n')
    
        scene_3()
     
    elif choice in ["2","two","ii"]:
        print("You avoided Squirt.\n")
        print("The current is strong and you get injured.\n")
        fail()
    
    else:
        print("Invalid choice. Please try again.")
        
        input(prompt='<Press enter to restart the game>\n')
        scene_1()



def scene_3():
    
    #Variable #4 - a list of strings to define the pearls to choose in the scene.
    pearls_items = ["Blue Pearl", "Pink Pearl", "Green Pearl", "Black Pearl", "Red Pearl", "White Pearl"]
    print("You made it to the last Coral Reef!\n")
    print("But, wait... This reef has some pearls on it.\n")
    
    #Variable #5 - a list of the collectible pearls that the user will collect.
    player_collection = []
    print("You reached a beautiful and unique coral reef")
    print("You see different types of pearls around you, do you want to collect some?\n")
    print("1. Yes\n2. No")
# This while loop will keep running until the player either chooses to collect 3 different types of pearls 
# or chooses to not collect any pearls.    
    while True:
        # The try-except block is used to catch any errors that may occur when the player enters an invalid input.
        try:
            # The player is prompted to enter their choice.
            choice = int(input(prompt="> "))
            # If the player chooses to collect pearls, they are prompted to 
            #pick a type of pearl from a list of options.
            if choice == 1 :
                print("Which type of pearls do you want to collect?\n")
                print("1. Blue Pearl \n2. Pink Pearl \n3. White Pearl")
                #Variable #6 - A variable to choose which pearl you will collect next.
                pearl_choice = int(input(prompt="Choose a number > "))
                
                # If the player makes a valid choice, the pearl is added to their collection 
                if pearl_choice in [1,2,3]:
                    player_collection.append(pearls_items[pearl_choice-1])
                    print("You added a piece of ", pearls_items[pearl_choice-1], "to your collection.\n")
                    if len(player_collection) < 3:
                        print("Do you want to collect more pearls?\n")
                        print("1. Yes\n2. No")
                    else:
                        print("Congratulations! You have collected 3 different types of pearls.\n")
                        print("You passed the challenge and are now able to return home safely.\n")
                        #Calling the win function when the player completes the game
                        win()
                        break
                else:
                    print("Invalid choice. Please try again.")
            elif choice == 2:
                print("You decide to not collect any pearl.")
                print("Thanks for playing!")
                fail()
                break
            else:
                raise ValueError
        except ValueError:
            print("Invalid choice. Please enter a valid number.")

            #Define the win function
def win():
    
    print("Dori and Marlin are on the coral reef, they been looking for you everywhere.")
    print("You can return home safe")
    print("YOU WIN!!!")
    
#Define the fail function used and called from different parts as you can lose
#in more than one part
def fail():
    
    print("GAME OVER")
    input(prompt='<Press enter to try again>\n')
    scene_1()

    
scene_1() #All the code go before this function to start the game
# Out:
# Hello! Welcome to the "Finding Nemo Game"
#
# This is a text adventure game in which you will be Nemo and will be trying to return home.
#
# Are you ready for the adventure?
#
#
#
#   ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢀⣀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢀⣠⣾⣿⣿⣷⣄⠀⠀⠀⠀⠀⠀⠀⠀⠀
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢀⡔⠭⠍⡙⠉⠔⠁⠀⠈⠻⣿⣇⠀⠀⠀⠀⠀⠀⠀⠀
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣸⠄⡀⠀⠀⢀⣉⣈⠁⢢⠀⢹⣿⡆⠀⠀⠀⠀⠀⠀⠀
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢀⠎⢠⣴⣶⠀⠌⠀⣀⣀⢱⠀⡇⠀⣿⣷⠀⠀⠀⠀⠀⠀⠀
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣀⣀⣀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢸⠀⣿⣿⡟⢸⠀⣼⣿⣿⡿⠀⡇⠀⢸⣿⡀⠀⠀⠀⠀⠀⠀
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⣠⣾⣿⣿⣿⣿⣷⣶⣄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⢢⠼⠋⠀⠈⢆⠹⠿⡿⠁⡸⠀⠀⢸⣿⡇⠀⠀⠀⠀⠀⠀
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠻⣿⣿⣿⣿⣿⣿⣿⣿⠿⠓⢐⣄⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⡇⠀⠀⠀⠀⠀⠈⠁⠀⢠⠃⣠⡄⢸⣿⣿⠀⠀⠀⢀⣀⡀
# ⠀⠀⠀⠀⠀⠀⠀⢀⣀⡀⠈⢿⣿⣿⣿⣿⡟⢡⣴⣾⣿⣿⣿⣆⠀⠀⠀⠀⠀⠀⠀⡤⠊⠀⠀⠀⠀⠀⠀⠀⠀⠀⡌⣼⣿⡇⠈⡏⠙⠀⡠⣖⣵⠏⠀
# ⠀⠀⠀⠀⠀⠀⣸⣿⣿⣿⡀⠀⠙⢿⣿⣿⢁⣿⣿⣿⣿⣿⣿⣯⡁⠀⠀⠀⠀⠀⠀⢆⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⡇⣿⣿⡇⠀⠈⢈⣡⣾⣿⣿⠀⠀
# ⠀⢀⣤⣶⣶⣶⣾⡙⣿⣿⣷⡀⢰⣶⣿⣿⢸⣿⡿⣫⣍⠙⣿⣿⣇⣰⡄⠀⠀⠀⠀⡎⢿⡷⠒⠂⠀⠀⠀⠀⠀⠀⠇⠙⠛⠁⠀⢠⣿⣿⣿⣿⣿⡆⠀
# ⢠⣿⣿⣿⣿⣿⣿⣷⡙⢿⣿⣧⠘⠿⢻⣿⣸⣿⣇⠈⠉⣀⣾⣿⣿⣿⠇⠀⠀⠀⠈⠦⢤⠀⠀⠀⠀⠀⠀⠀⠀⠀⠘⢄⣠⠖⣣⢸⣿⣿⣿⣿⣿⠇⠀
# ⢸⣿⣿⣿⣿⣿⣿⣿⡇⣸⣿⣿⡆⢀⣾⣿⣧⢿⣿⣿⣿⣿⣿⣭⣽⡟⠀⠀⠀⠀⠀⢀⣼⡆⠀⠀⠀⠀⠀⠀⠀⣀⣢⡀⠀⡴⠉⢜⣿⣿⣿⣿⡟⠀⠀
# ⠈⢿⣿⣿⣿⣿⠟⠁⠀⠘⠛⠛⠁⠀⠀⠈⢿⠏⠛⠛⠛⠛⠛⠋⠁⠀⠀⠀⢀⣤⣾⣿⣿⣧⠀⠀⠀⠀⠀⠘⣸⣿⣿⣿⣞⠀⠀⠈⣾⣿⣿⠟⠀⠀⠀
# ...
